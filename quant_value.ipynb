# %%
import numpy as np
import pandas as pd
import requests
import math
from scipy.stats import percentileofscore as pofs
import xlsxwriter
import warnings

warnings.filterwarnings('ignore')

# %%
stocks = pd.read_csv('./sp_500_stocks.csv')
token = 'Tpk_059b97af715d417d9f49f50b51b1c448'

# %%
symbol = 'AAPL'
api_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/quote/?token={token}'
data = requests.get(api_url).json()

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n]
        
symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = []
for i in range(len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))

my_columns = ['Ticker', 'Price', 'Price-to-Earning Ratio', 'Number of Shares to Buy']

# %%
final_df = pd.DataFrame(columns=my_columns)
for symbol_string in symbol_strings: 
    batch_api_call_url = f'https://sandbox.iexapis.com/stable/stock/market/batch?symbols={symbol_string}&types=quote&token={token}'
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        try:
            final_df = final_df.append(pd.Series([symbol, 
                                       data[symbol]['quote']['latestPrice'], 
                                       data[symbol]['quote']['peRatio'], 
                                       'N/A'], index=my_columns), ignore_index=True)
        except:
            pass

# %%
final_df.sort_values(by='Price-to-Earning Ratio', ascending=True, inplace=True)
final_df = final_df[final_df['Price-to-Earning Ratio'] > 0]
final_df = final_df[:50]
final_df.reset_index(drop=True, inplace=True)

# %%
def portfolio_input():
    global portfolio_size
    portfolio_size = input('Enter the size of your portfolio: ')
    
    try:
        float(portfolio_size)
    except ValueError:
        print('Not a Number')
        portfolio_size = input('Enter the size of your portfolio: ')

# %%
portfolio_input()
# Out:
# Enter the size of your portfolio: 1000000

# %%
position_size = float(portfolio_size) / len(final_df.index)
for i in range(len(final_df.index)):
    final_df.loc[i, 'Number of Shares to Buy'] = math.floor(position_size / final_df.loc[i, 'Price'])

# %%
final_df
# Out:
#    Ticker    Price Price-to-Earning Ratio Number of Shares to Buy
# 0     VTR    38.81                 934.21                     515
# 1     GPN   114.64                  433.3                     174
# 2     NOW   372.23                  399.4                      53
# 3     STZ   231.65                 383.09                      86
# 4     CRM    159.3                 298.31                     125
# 5     KSU   307.23                 285.84                      65
# 6     DAL    32.71                 257.75                     611
# 7    APTV    85.02                 211.91                     235
# 8    DXCM    98.18                 204.46                     203
# 9     ALB   259.91                 119.13                      76
# 10   AMZN   117.38                 105.81                     170
# 11   TMUS   139.88                 102.35                     142
# 12    ZBH   107.79                 100.64                     185
# 13   TTWO   129.14                  94.56                     154
# 14    PGR   119.61                   87.3                     167
# 15    UDR    40.52                  82.18                     493
# 16   PAYC    321.5                  81.64                      62
# 17    TYL   345.56                  79.89                      57
# 18   SBAC   248.12                  79.43                      80
# 19   ADSK   202.72                  78.38                      98
# 20   EQIX    532.9                  78.33                      37
# 21    BSX    41.45                  72.02                     482
# 22    ARE   134.34                  70.46                     148
# 23   WELL     59.2                  70.14                     337
# 24   EBAY    39.17                  66.08                     510
# 25   FTNT    51.82                     65                     385
# 26   CBOE   124.78                  62.25                     160
# 27    VAR   181.53                  60.32                     110
# 28   ALXN    189.1                  59.84                     105
# 29    DIS   103.07                  57.88                     194
# 30    CMG   1557.7                   57.8                      12
# 31    FIS    80.35                  57.62                     248
# 32   INTU   404.85                  57.55                      49
# 33   PEAK    23.16                  56.33                     863
# 34    TIF   133.01                   56.3                     150
# 35   ABMD   264.33                  55.43                      75
# 36    NEE    71.86                   55.4                     278
# 37   CDNS   157.64                  55.11                     126
# 38    ROL    36.35                  54.65                     550
# 39      O    58.13                  54.56                     344
# 40   XLNX   198.07                   54.5                     100
# 41    LLY   337.39                  54.34                      59
# 42   ISRG      219                  54.31                      91
# 43   PYPL    88.98                  49.86                     224
# 44   BKNG  1787.43                  48.96                      11
# 45   CERN    96.13                  48.46                     208
# 46     MO    45.11                  46.27                     443
# 47   SNPS   291.72                  46.19                      68
# 48    STE   171.24                  45.54                     116
# 49   EXPE    97.46                   44.9                     205

# %%
rv_columns = [
    'Ticker',
    'Price',
    'Number of Shares to Buy',
    'Price-to-Earning Ratio',
    'PE Percentile',
    'Price-to-Book Ratio',
    'PB Percentile',
    'Price-to-Sales Ratio',
    'PS Percentile',
    'EV/EBITDA',
    'EV/EBITDA Percentile',
    'EV/GP',
    'EV/GP Percentile',
    'RV Score',
]

rv_df = pd.DataFrame(columns=rv_columns)

# %%
for symbol_string in symbol_strings:
    batch_api_call_url = f'https://sandbox.iexapis.com/stable/stock/market/batch?symbols={symbol_string}&types=quote,advanced-stats&token={token}'
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        try:
            enterprise_value = data[symbol]['advanced-stats']['enterpriseValue']
            ebitda = data[symbol]['advanced-stats']['EBITDA']
            gross_profit = data[symbol]['advanced-stats']['grossProfit']
            
            try:
                ev_to_ebitda = enterprise_value/ebitda
            except TypeError:
                ev_to_ebitda = np.NaN
                
            try:
                ev_to_gp = enterprise_value/gross_profit
            except TypeError:
                ev_to_gp = np.NaN 
            
            rv_df = rv_df.append(pd.Series([
                symbol,
                data[symbol]['quote']['latestPrice'],
                'N/A',
                data[symbol]['quote']['peRatio'],
                'N/A',
                data[symbol]['advanced-stats']['priceToBook'],
                'N/A',
                data[symbol]['advanced-stats']['priceToSales'],
                'N/A',
                ev_to_ebitda,
                'N/A',
                ev_to_gp,
                'N/A',
                'N/A',
            ], index=rv_columns), ignore_index=True)
        except:
            pass

# %%
len(rv_df[rv_df.isnull().any(axis=1)].index)
# Out:
# 21

# %%
rv_df.columns
# Out:
# Index(['Ticker', 'Price', 'Number of Shares to Buy', 'Price-to-Earning Ratio',
#        'PE Percentile', 'Price-to-Book Ratio', 'PB Percentile',
#        'Price-to-Sales Ratio', 'PS Percentile', 'EV/EBITDA',
#        'EV/EBITDA Percentile', 'EV/GP', 'EV/GP Percentile', 'RV Score'],
#       dtype='object')

# %%
for col in ['Price', 'Price-to-Earning Ratio', 'Price-to-Book Ratio', 'Price-to-Sales Ratio', 'EV/EBITDA', 'EV/GP']:
    rv_df[col].fillna(rv_df[col].mean(), inplace=True)

# %%
rv_df
# Out:
#     Ticker   Price Number of Shares to Buy  Price-to-Earning Ratio  \
# 0        A  130.06                     N/A                   29.50
# 1      AAL   13.72                     N/A                   -4.82
# 2      AAP  173.18                     N/A                   20.30
# 3     AAPL  148.96                     N/A                   23.90
# 4     ABBV  147.28                     N/A                   20.89
# ..     ...     ...                     ...                     ...
# 496    YUM  113.44                     N/A                   22.02
# 497    ZBH  109.57                     N/A                   99.82
# 498   ZBRA  261.87                     N/A                   28.14
# 499   ZION   48.55                     N/A                    5.40
# 500    ZTS  150.10                     N/A                   33.92
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0             N/A                 7.80           N/A                5.8300
# 1             N/A                -1.09           N/A                0.2284
# 2             N/A                 3.69           N/A                0.9630
# 3             N/A                41.55           N/A                6.2400
# 4             N/A                17.51           N/A                4.4200
# ..            ...                  ...           ...                   ...
# 496           N/A                -3.75           N/A                4.8700
# 497           N/A                 1.96           N/A                3.2000
# 498           N/A                 5.40           N/A                2.3600
# 499           N/A                 1.50           N/A                2.1900
# 500           N/A                15.42           N/A                8.9600
#
#     PS Percentile   EV/EBITDA EV/EBITDA Percentile      EV/GP  \
# 0             N/A   20.578313                  N/A  11.026167
# 1             N/A  106.578085                  N/A   0.824370
# 2             N/A   11.433411                  N/A   2.352374
# 3             N/A   18.361671                  N/A  14.207764
# 4             N/A   11.732776                  N/A   7.964192
# ..            ...         ...                  ...        ...
# 496           N/A   19.158053                  N/A   8.693135
# 497           N/A   17.460372                  N/A   5.450450
# 498           N/A   14.758825                  N/A   5.857592
# 499           N/A    4.544861                  N/A   2.074147
# 500           N/A   24.557408                  N/A  13.136826
#
#     EV/GP Percentile RV Score
# 0                N/A      N/A
# 1                N/A      N/A
# 2                N/A      N/A
# 3                N/A      N/A
# 4                N/A      N/A
# ..               ...      ...
# 496              N/A      N/A
# 497              N/A      N/A
# 498              N/A      N/A
# 499              N/A      N/A
# 500              N/A      N/A
#
# [501 rows x 14 columns]

# %%
metrics = {
    'Price-to-Earning Ratio':'PE Percentile',
    'Price-to-Book Ratio':'PB Percentile',
    'Price-to-Sales Ratio':'PS Percentile',
    'EV/EBITDA':'EV/EBITDA Percentile',
    'EV/GP':'EV/GP Percentile',
}

# %%
for metric in metrics.keys():
    for row in rv_df.index:
        rv_df.loc[row, metrics[metric]] = pofs(rv_df[metric], rv_df.loc[row, metric]) / 100

# %%
rv_df
# Out:
#     Ticker   Price Number of Shares to Buy  Price-to-Earning Ratio  \
# 0        A  130.06                     N/A                   29.50
# 1      AAL   13.72                     N/A                   -4.82
# 2      AAP  173.18                     N/A                   20.30
# 3     AAPL  148.96                     N/A                   23.90
# 4     ABBV  147.28                     N/A                   20.89
# ..     ...     ...                     ...                     ...
# 496    YUM  113.44                     N/A                   22.02
# 497    ZBH  109.57                     N/A                   99.82
# 498   ZBRA  261.87                     N/A                   28.14
# 499   ZION   48.55                     N/A                    5.40
# 500    ZTS  150.10                     N/A                   33.92
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0        0.750499                 7.80      0.796407                5.8300
# 1        0.033932                -1.09       0.05988                0.2284
# 2        0.516966                 3.69      0.555888                0.9630
# 3        0.618762                41.55      0.978044                6.2400
# 4         0.53493                17.51      0.938124                4.4200
# ..            ...                  ...           ...                   ...
# 496       0.56487                -3.75      0.055888                4.8700
# 497      0.976048                 1.96      0.338323                3.2000
# 498      0.726547                 5.40      0.698603                2.3600
# 499      0.087824                 1.50      0.221557                2.1900
# 500      0.816367                15.42      0.928144                8.9600
#
#     PS Percentile   EV/EBITDA EV/EBITDA Percentile      EV/GP  \
# 0        0.842315   20.578313             0.838323  11.026167
# 1        0.013972  106.578085             0.996008   0.824370
# 2        0.159681   11.433411             0.411178   2.352374
# 3        0.858283   18.361671             0.766467  14.207764
# 4        0.758483   11.732776             0.427146   7.964192
# ..            ...         ...                  ...        ...
# 496      0.804391   19.158053             0.790419   8.693135
# 497       0.60479   17.460372             0.732535   5.450450
# 498      0.447106   14.758825              0.62475   5.857592
# 499      0.427146    4.544861             0.087824   2.074147
# 500      0.922156   24.557408             0.916168  13.136826
#
#     EV/GP Percentile RV Score
# 0           0.826347      N/A
# 1            0.02994      N/A
# 2           0.149701      N/A
# 3           0.918164      N/A
# 4           0.666667      N/A
# ..               ...      ...
# 496         0.722555      N/A
# 497         0.431138      N/A
# 498         0.469062      N/A
# 499         0.131737      N/A
# 500         0.902196      N/A
#
# [501 rows x 14 columns]

# %%
from statistics import mean

for row in rv_df.index:
    value_percentiles = []
    for metric in metrics.keys():
        value_percentiles.append(rv_df.loc[row, metrics[metric]])
    rv_df.loc[row, 'RV Score'] = mean(value_percentiles)

# %%
rv_df
# Out:
#     Ticker   Price Number of Shares to Buy  Price-to-Earning Ratio  \
# 0        A  130.06                     N/A                   29.50
# 1      AAL   13.72                     N/A                   -4.82
# 2      AAP  173.18                     N/A                   20.30
# 3     AAPL  148.96                     N/A                   23.90
# 4     ABBV  147.28                     N/A                   20.89
# ..     ...     ...                     ...                     ...
# 496    YUM  113.44                     N/A                   22.02
# 497    ZBH  109.57                     N/A                   99.82
# 498   ZBRA  261.87                     N/A                   28.14
# 499   ZION   48.55                     N/A                    5.40
# 500    ZTS  150.10                     N/A                   33.92
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0        0.750499                 7.80      0.796407                5.8300
# 1        0.033932                -1.09       0.05988                0.2284
# 2        0.516966                 3.69      0.555888                0.9630
# 3        0.618762                41.55      0.978044                6.2400
# 4         0.53493                17.51      0.938124                4.4200
# ..            ...                  ...           ...                   ...
# 496       0.56487                -3.75      0.055888                4.8700
# 497      0.976048                 1.96      0.338323                3.2000
# 498      0.726547                 5.40      0.698603                2.3600
# 499      0.087824                 1.50      0.221557                2.1900
# 500      0.816367                15.42      0.928144                8.9600
#
#     PS Percentile   EV/EBITDA EV/EBITDA Percentile      EV/GP  \
# 0        0.842315   20.578313             0.838323  11.026167
# 1        0.013972  106.578085             0.996008   0.824370
# 2        0.159681   11.433411             0.411178   2.352374
# 3        0.858283   18.361671             0.766467  14.207764
# 4        0.758483   11.732776             0.427146   7.964192
# ..            ...         ...                  ...        ...
# 496      0.804391   19.158053             0.790419   8.693135
# 497       0.60479   17.460372             0.732535   5.450450
# 498      0.447106   14.758825              0.62475   5.857592
# 499      0.427146    4.544861             0.087824   2.074147
# 500      0.922156   24.557408             0.916168  13.136826
#
#     EV/GP Percentile  RV Score
# 0           0.826347  0.810778
# 1            0.02994  0.226747
# 2           0.149701  0.358683
# 3           0.918164  0.827944
# 4           0.666667   0.66507
# ..               ...       ...
# 496         0.722555  0.587625
# 497         0.431138  0.616567
# 498         0.469062  0.593214
# 499         0.131737  0.191218
# 500         0.902196  0.897006
#
# [501 rows x 14 columns]

# %%
rv_df.sort_values(by='RV Score', ascending=True, inplace=True)
rv_df = rv_df[:50]
rv_df.reset_index(drop=True, inplace=True)
rv_df
# Out:
#    Ticker   Price Number of Shares to Buy  Price-to-Earning Ratio  \
# 0     PVH   49.14                     N/A                    3.58
# 1     AIG   52.35                     N/A                    3.52
# 2     KSS   28.80                     N/A                    5.67
# 3       F   12.20                     N/A                    4.14
# 4      GM   34.66                     N/A                    6.68
# 5       C   44.28                     N/A                    5.70
# 6     SYF   31.73                     N/A                    4.76
# 7     COF   98.82                     N/A                    4.34
# 8     UAA    6.95                     N/A                    8.81
# 9     HPQ   25.70                     N/A                    4.45
# 10    CAH   72.03                     N/A                  -21.47
# 11    PHM   37.53                     N/A                    4.25
# 12    UNM   43.18                     N/A                    8.11
# 13    MHK   94.40                     N/A                    6.42
# 14    TSN   67.70                     N/A                    6.01
# 15    WDC   35.10                     N/A                    7.10
# 16    LEN   72.61                     N/A                    4.79
# 17    LNC   48.95                     N/A                   10.11
# 18    NRG   42.52                     N/A                    2.89
# 19    DHI   68.68                     N/A                    4.39
# 20    UHS   97.99                     N/A                    9.59
# 21   DISH   14.46                     N/A                    4.50
# 22    CCL    8.00                     N/A                   -1.34
# 23    AIZ  151.10                     N/A                    6.90
# 24    BEN   22.76                     N/A                    6.63
# 25    IVZ   14.46                     N/A                    6.31
# 26    GPS   10.05                     N/A                  -10.09
# 27      T   17.34                     N/A                    6.30
# 28    FDX  151.70                     N/A                   11.21
# 29      L   56.10                     N/A                   12.47
# 30    PFG   80.30                     N/A                    4.96
# 31    NUE  129.96                     N/A                    4.02
# 32    WBA   34.38                     N/A                    6.86
# 33    WRK   33.55                     N/A                    9.37
# 34    HCA  217.29                     N/A                   10.17
# 35    HPE   13.04                     N/A                    4.79
# 36     RL   93.50                     N/A                   12.16
# 37     IP   33.18                     N/A                    6.71
# 38     GS  312.18                     N/A                    7.18
# 39   INTC   26.42                     N/A                    5.70
# 40    DXC   29.48                     N/A                   13.40
# 41    HIG   68.46                     N/A                   11.21
# 42    DOW   45.10                     N/A                    5.07
# 43  CMCSA   31.70                     N/A                   10.04
# 44    VLO  125.47                     N/A                    7.36
# 45    LYB   80.61                     N/A                    4.86
# 46    MPC  110.44                     N/A                    7.88
# 47    WHR  137.77                     N/A                   11.20
# 48    PSX   99.39                     N/A                    8.30
# 49    KEY   16.34                     N/A                    6.97
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.051896               0.6153       0.06986                0.3495
# 1         0.0499               0.9165        0.0998                0.7268
# 2        0.08982               0.7569      0.081836                0.1843
# 3       0.055888               1.1200      0.132735                0.3275
# 4       0.113772               0.7936      0.083832                0.3866
# 5       0.092814               0.4733      0.065868                1.0000
# 6       0.070858               1.2000      0.145709                0.9035
# 7        0.05988               0.7178      0.073852                1.1100
# 8       0.157685               1.3400      0.177645                0.4928
# 9       0.063872             -11.3300      0.043912                0.4045
# 10      0.017964             -26.3600      0.027944                0.1058
# 11      0.057884               1.1200      0.132735                0.5846
# 12      0.145709               0.9305      0.105788                0.7600
# 13       0.10978               0.7187      0.075848                0.5206
# 14      0.095808               0.9828       0.10978                0.3601
# 15      0.129741               0.8865      0.093812                0.5896
# 16       0.07485               0.9244      0.101796                0.6487
# 17      0.207585               0.9060      0.097804                0.4246
# 25      0.183633   6.745263             0.181637  1.853324         0.111776
# 26      0.015968  10.279759             0.335329  0.848665         0.035928
# 27      0.125749   5.197796              0.10978  3.046085         0.227545
# 28      0.055888   5.144627             0.107784  0.568794         0.007984
# 29      0.169661   4.579746              0.08982  0.969751           0.0499
# 30      0.219561   3.490226             0.045908  1.099155          0.05988
# 31      0.127745   2.715252             0.021956  2.554149         0.169661
# 32       0.00998  10.704674             0.359281  1.334208         0.077844
# 33      0.051896   4.764878               0.0998  3.938566         0.299401
# 34      0.185629   7.984162             0.237525  1.658251         0.095808
# 35      0.091816  10.193778             0.331337  2.741164         0.189621
# 36        0.0998   3.771493             0.051896  0.900255         0.041916
# 37      0.093812   6.658231             0.175649  3.595845         0.265469
# 38      0.358283   4.850209             0.101796  1.901864         0.113772
# 39      0.278443   4.623393             0.091816  3.139832         0.237525
# 40       0.05988   4.268230             0.071856  2.615932         0.175649
# 41      0.179641   4.864853             0.103792  0.961990         0.047904
# 42      0.077844   4.651595             0.093812  3.959055         0.305389
# 43      0.199601   5.845401             0.133733  1.771852         0.103792
# 44      0.023952   4.541960             0.083832  2.967397         0.221557
# 45       0.06986   3.946035              0.05988  3.907692         0.293413
# 46      0.031936   4.197839              0.06986  3.624793         0.271457
# 47      0.041916   5.393701             0.117764  2.720878         0.183633
# 48      0.025948   5.247400             0.111776  3.756706         0.287425
# 49      0.399202   5.289275             0.113772  1.992302         0.123752
#
#     RV Score
# 0   0.051497
# 1   0.058683
# 2    0.05988
# 3   0.069661
# 4   0.070259
# 5   0.083633
# 6   0.086028
# 7   0.086228
# 8   0.086627
# 9    0.09022
# 10  0.090619
# 11  0.092415
# 12   0.09501
# 13  0.098603
# 14  0.108583
# 15  0.111776
# 16  0.113174
# 17  0.114571
# 18  0.116567
# 19  0.116966
# 20  0.117764
# 21   0.11976
# 22   0.12016
# 23  0.126148
# 24  0.127745
# 25  0.129541
# 26  0.132934
# 27   0.13493
# 28   0.13513
# 29  0.138922
# 30  0.139321
# 31  0.139321
# 32  0.141118
# 33  0.142116
# 34  0.151697
# 35  0.154691
# 36  0.156088
# 37  0.164471
# 38  0.164671
# 39   0.16507
# 40   0.16507
# 41  0.167066
# 42   0.17006
# 43  0.172056
# 44  0.176846
# 45  0.178842
# 46  0.179441
# 47   0.18024
# 48  0.180639
# 49  0.182635

# %%
portfolio_input()
# Out:
# Enter the size of your portfolio: 2500000

# %%
position_size = float(portfolio_size) / len(rv_df.index)
for i in range(len(rv_df.index)):
    rv_df.loc[i, 'Number of Shares to Buy'] = math.floor(position_size / rv_df.loc[i, 'Price'])

# %%
rv_df
# Out:
#    Ticker   Price Number of Shares to Buy  Price-to-Earning Ratio  \
# 0     PVH   49.14                    1017                    3.58
# 1     AIG   52.35                     955                    3.52
# 2     KSS   28.80                    1736                    5.67
# 3       F   12.20                    4098                    4.14
# 4      GM   34.66                    1442                    6.68
# 5       C   44.28                    1129                    5.70
# 6     SYF   31.73                    1575                    4.76
# 7     COF   98.82                     505                    4.34
# 8     UAA    6.95                    7194                    8.81
# 9     HPQ   25.70                    1945                    4.45
# 10    CAH   72.03                     694                  -21.47
# 11    PHM   37.53                    1332                    4.25
# 12    UNM   43.18                    1157                    8.11
# 13    MHK   94.40                     529                    6.42
# 14    TSN   67.70                     738                    6.01
# 15    WDC   35.10                    1424                    7.10
# 16    LEN   72.61                     688                    4.79
# 17    LNC   48.95                    1021                   10.11
# 18    NRG   42.52                    1175                    2.89
# 19    DHI   68.68                     728                    4.39
# 20    UHS   97.99                     510                    9.59
# 21   DISH   14.46                    3457                    4.50
# 22    CCL    8.00                    6250                   -1.34
# 23    AIZ  151.10                     330                    6.90
# 24    BEN   22.76                    2196                    6.63
# 25    IVZ   14.46                    3457                    6.31
# 26    GPS   10.05                    4975                  -10.09
# 27      T   17.34                    2883                    6.30
# 28    FDX  151.70                     329                   11.21
# 29      L   56.10                     891                   12.47
# 30    PFG   80.30                     622                    4.96
# 31    NUE  129.96                     384                    4.02
# 32    WBA   34.38                    1454                    6.86
# 33    WRK   33.55                    1490                    9.37
# 34    HCA  217.29                     230                   10.17
# 35    HPE   13.04                    3834                    4.79
# 36     RL   93.50                     534                   12.16
# 37     IP   33.18                    1506                    6.71
# 38     GS  312.18                     160                    7.18
# 39   INTC   26.42                    1892                    5.70
# 40    DXC   29.48                    1696                   13.40
# 41    HIG   68.46                     730                   11.21
# 42    DOW   45.10                    1108                    5.07
# 43  CMCSA   31.70                    1577                   10.04
# 44    VLO  125.47                     398                    7.36
# 45    LYB   80.61                     620                    4.86
# 46    MPC  110.44                     452                    7.88
# 47    WHR  137.77                     362                   11.20
# 48    PSX   99.39                     503                    8.30
# 49    KEY   16.34                    3059                    6.97
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.051896               0.6153       0.06986                0.3495
# 1         0.0499               0.9165        0.0998                0.7268
# 2        0.08982               0.7569      0.081836                0.1843
# 3       0.055888               1.1200      0.132735                0.3275
# 4       0.113772               0.7936      0.083832                0.3866
# 5       0.092814               0.4733      0.065868                1.0000
# 6       0.070858               1.2000      0.145709                0.9035
# 7        0.05988               0.7178      0.073852                1.1100
# 8       0.157685               1.3400      0.177645                0.4928
# 9       0.063872             -11.3300      0.043912                0.4045
# 10      0.017964             -26.3600      0.027944                0.1058
# 11      0.057884               1.1200      0.132735                0.5846
# 12      0.145709               0.9305      0.105788                0.7600
# 13       0.10978               0.7187      0.075848                0.5206
# 14      0.095808               0.9828       0.10978                0.3601
# 15      0.129741               0.8865      0.093812                0.5896
# 16       0.07485               0.9244      0.101796                0.6487
# 17      0.207585               0.9060      0.097804                0.4246
# 18      0.047904               1.8800      0.313373                0.3549
# 19      0.061876               1.3000      0.171657                0.7431
# 20      0.184631               1.0900      0.128743                0.4949
# 21      0.065868               0.2459      0.061876                0.2340
# 22      0.041916               1.0400       0.11976                0.8975
# 23       0.11976               1.8800      0.313373                0.8143
# 24      0.111776               0.9993      0.111776                1.3000
# 25      0.106786               0.4515      0.063872                1.0382
# 26      0.027944               1.6200      0.249501                0.2333
# 27      0.103792               0.9413      0.107784                0.7640
# 28      0.248503               1.6300      0.255489                0.4203
# 29      0.293413               0.8749      0.091816                0.9900
# 35      0.091816  10.193778             0.331337  2.741164         0.189621
# 36        0.0998   3.771493             0.051896  0.900255         0.041916
# 37      0.093812   6.658231             0.175649  3.595845         0.265469
# 38      0.358283   4.850209             0.101796  1.901864         0.113772
# 39      0.278443   4.623393             0.091816  3.139832         0.237525
# 40       0.05988   4.268230             0.071856  2.615932         0.175649
# 41      0.179641   4.864853             0.103792  0.961990         0.047904
# 42      0.077844   4.651595             0.093812  3.959055         0.305389
# 43      0.199601   5.845401             0.133733  1.771852         0.103792
# 44      0.023952   4.541960             0.083832  2.967397         0.221557
# 45       0.06986   3.946035              0.05988  3.907692         0.293413
# 46      0.031936   4.197839              0.06986  3.624793         0.271457
# 47      0.041916   5.393701             0.117764  2.720878         0.183633
# 48      0.025948   5.247400             0.111776  3.756706         0.287425
# 49      0.399202   5.289275             0.113772  1.992302         0.123752
#
#     RV Score
# 0   0.051497
# 1   0.058683
# 2    0.05988
# 3   0.069661
# 4   0.070259
# 5   0.083633
# 6   0.086028
# 7   0.086228
# 8   0.086627
# 9    0.09022
# 10  0.090619
# 11  0.092415
# 12   0.09501
# 13  0.098603
# 14  0.108583
# 15  0.111776
# 16  0.113174
# 17  0.114571
# 18  0.116567
# 19  0.116966
# 20  0.117764
# 21   0.11976
# 22   0.12016
# 23  0.126148
# 24  0.127745
# 25  0.129541
# 26  0.132934
# 27   0.13493
# 28   0.13513
# 29  0.138922
# 30  0.139321
# 31  0.139321
# 32  0.141118
# 33  0.142116
# 34  0.151697
# 35  0.154691
# 36  0.156088
# 37  0.164471
# 38  0.164671
# 39   0.16507
# 40   0.16507
# 41  0.167066
# 42   0.17006
# 43  0.172056
# 44  0.176846
# 45  0.178842
# 46  0.179441
# 47   0.18024
# 48  0.180639
# 49  0.182635

# %%
writer = pd.ExcelWriter('value_strategy.xlsx', engine='xlsxwriter')
rv_df.to_excel(writer, 'Value Strategy', index = False)

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
    {
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)
dollar_format = writer.book.add_format(
    {
        'num_format': '$0.00',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)
integer_format = writer.book.add_format(
    {
        'num_format': '0',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)
float_format = writer.book.add_format(
    {
        'num_format': '0.0',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)
percentile_format = writer.book.add_format(
    {
        'num_format': '0.00%',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

# %%
column_formats = {
   'A': ['Ticker', string_format],
   'B': ['Price', dollar_format],
   'C': ['Number of Shares to Buy', integer_format],
   'D': ['Price-to-Earning Ratio', float_format],
   'E': ['PE Percentile', percentile_format],
   'F': ['Price-to-Book Ratio', float_format],
   'G': ['PB Percentile', percentile_format],
   'H': ['Price-to-Sales Ratio', float_format],
   'I': ['PS Percentile', percentile_format],
   'J': ['EV/EBITDA', float_format],
   'K': ['EV/EBITDA Percentile', percentile_format],
   'L': ['EV/GP', float_format],
   'M': ['EV/GP Percentile', percentile_format],
   'N': ['RV Score', percentile_format],
}

for col in column_formats.keys():
    writer.sheets['Value Strategy'].set_column(f'{col}:{col}', 25, column_formats[col][1])
    writer.sheets['Value Strategy'].write(f'{col}1', column_formats[col][0], column_formats[col][1])
writer.save()

# %%
writer.close()
